# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
file_path = "/Users/sabari/Documents/DS/GUVI/dspatrol/PatrolIQ-Smart_Safety_Analytics_Platform-main/data/Crimes_-_2001_to_Present_20260302.csv"

df = pd.read_csv(file_path)

print("Dataset Loaded Successfully ✅")
# Out:
# Dataset Loaded Successfully ✅

# %%
print("Dataset Shape :", df.shape)
# Out:
# Dataset Shape : (8504238, 22)

# %%
df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  14117226    JK157149  02/21/2026 12:00:00 AM       035XX W 63RD ST  0530
# 1  14118508    JK158813  02/21/2026 12:00:00 AM    072XX W ADDISON ST  0460
# 2  14117209    JK157113  02/21/2026 12:00:00 AM    012XX N KEELER AVE  1310
# 3  14117438    JK157387  02/21/2026 12:00:00 AM     049XX N MARINE DR  2826
# 4  14117621    JK157505  02/21/2026 12:00:00 AM  080XX S CARPENTER ST  1310
#
#       Primary Type                          Description Location Description  \
# 0          ASSAULT  AGGRAVATED - OTHER DANGEROUS WEAPON               STREET
# 1          BATTERY                               SIMPLE               STREET
# 2  CRIMINAL DAMAGE                          TO PROPERTY            APARTMENT
# 3    OTHER OFFENSE       HARASSMENT BY ELECTRONIC MEANS            APARTMENT
# 4  CRIMINAL DAMAGE                          TO PROPERTY            APARTMENT
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8504238 entries, 0 to 8504237
# Data columns (total 22 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Case Number           object
#  2   Date                  object
#  3   Block                 object
#  4   IUCR                  object
#  5   Primary Type          object
#  6   Description           object
#  7   Location Description  object
#  8   Arrest                bool
#  9   Domestic              bool
#  10  Beat                  int64
#  11  District              float64
#  12  Ward                  float64
#  13  Community Area        float64
#  14  FBI Code              object
#  15  X Coordinate          float64
#  16  Y Coordinate          float64
#  17  Year                  int64
#  18  Updated On            object
#  19  Latitude              float64
#  20  Longitude             float64
#  21  Location              object
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Ward                    614818
# Community Area          613685
# Location                 94722
# Longitude                94722
# Latitude                 94722
# Y Coordinate             94722
# X Coordinate             94722
# Location Description     15650
# District                    47
# Domestic                     0
# Beat                         0
# Case Number                  0
# Arrest                       0
# Description                  0
# FBI Code                     0
# Primary Type                 0
# IUCR                         0
# Year                         0
# Updated On                   0
# Block                        0
# Date                         0
# ID                           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_sample = df.sample(n=500000, random_state=42)

print("Sample Shape :", df_sample.shape)
# Out:
# Sample Shape : (500000, 22)

# %%
save_path = "/Users/sabari/Documents/DS/GUVI/dspatrol/PatrolIQ-Smart_Safety_Analytics_Platform-main/data/Crime_sample.csv"
df_sample.to_csv(save_path, index=False)

print("Sample Dataset Saved Successfully ✅")
# Out:
# Sample Dataset Saved Successfully ✅

# %%
df_sample['Primary Type'].value_counts().head(10)
# Out:
# Primary Type
# THEFT                  105842
# BATTERY                 91164
# CRIMINAL DAMAGE         56598
# NARCOTICS               45114
# ASSAULT                 33778
# OTHER OFFENSE           31006
# BURGLARY                26500
# MOTOR VEHICLE THEFT     25635
# DECEPTIVE PRACTICE      23176
# ROBBERY                 18593
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

df_sample['Primary Type'].value_counts().head(10).plot(kind='bar')

plt.title("Top 10 Crime Types")
plt.xlabel("Crime Type")
plt.ylabel("Count")

plt.show()

# %%
df_sample['Date'] = pd.to_datetime(df_sample['Date'])
# Out:
# /var/folders/pp/g4gxxt1n4msf_38rzlmv0c9w0000gn/T/ipykernel_32379/3239346728.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_sample['Date'] = pd.to_datetime(df_sample['Date'])

# %%
df_sample['Year'].value_counts().sort_index()
# Out:
# Year
# 2001    28564
# 2002    28530
# 2003    27867
# 2004    27958
# 2005    26552
# 2006    26284
# 2007    25728
# 2008    25254
# 2009    22768
# 2010    21782
# 2011    20445
# 2012    19579
# 2013    18188
# 2014    16360
# 2015    15636
# 2016    15987
# 2017    15750
# 2018    15895
# 2019    15338
# 2020    12566
# 2021    12429
# 2022    14210
# 2023    15526
# 2024    15185
# 2025    13917
# 2026     1702
# Name: count, dtype: int64
